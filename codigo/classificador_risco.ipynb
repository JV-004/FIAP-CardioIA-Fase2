# %% [markdown]
# # CardioIA – Parte 2: Classificador de Risco Clínico
#
# **Responsável: Pessoa 3 – Machine Learning**
#
# Objetivo: utilizar TF-IDF + modelo de classificação para prever se uma frase de paciente representa **alto risco** ou **baixo risco**.
#
# ---
#
# ### Tarefas desta etapa:
# 1. Ler o arquivo `../dados/dataset_risco.csv`
# 2. Aplicar TF-IDF para transformar texto em vetores numéricos
# 3. Treinar um modelo (Decision Tree ou Logistic Regression)
# 4. Testar o modelo com dados de teste
# 5. Avaliar a acurácia e exibir o relatório de classificação

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# TODO: carregar o dataset_risco.csv
# df = pd.read_csv('../dados/dataset_risco.csv')

# %%
# TODO: separar X (frases) e y (situacao)
# TODO: dividir em treino e teste com train_test_split

# %%
# TODO: aplicar TfidfVectorizer nas frases

# %%
# TODO: escolher e treinar um modelo (LogisticRegression ou DecisionTreeClassifier)

# %%
# TODO: avaliar o modelo com accuracy_score e classification_report

# %%
# TODO: testar com novas frases criadas pelo grupo
